# %%
import os
import glob
from PIL import Image
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
dataset_path = "/home/hjx/Dataset/ISPRS/Potsdam"

# %%
folders = os.walk(dataset_path)
for root, dirs, files in folders:
#     for name in files:
#         print(os.path.join(root, name))
    for name in dirs:
        print(os.path.join(root, name))
# Out:
# /home/hjx/Dataset/ISPRS/Potsdam/5_Labels_for_participants_no_Boundary
# /home/hjx/Dataset/ISPRS/Potsdam/4_Ortho_RGBIR
# /home/hjx/Dataset/ISPRS/Potsdam/2_Ortho_RGB
# /home/hjx/Dataset/ISPRS/Potsdam/5_Labels_all
# /home/hjx/Dataset/ISPRS/Potsdam/1_DSM
# /home/hjx/Dataset/ISPRS/Potsdam/1_DSM_normalisation
# /home/hjx/Dataset/ISPRS/Potsdam/5_Labels_for_participants
# /home/hjx/Dataset/ISPRS/Potsdam/5_Labels_all_noBoundary
# /home/hjx/Dataset/ISPRS/Potsdam/3_Ortho_IRRG

# %%
os.listdir("/home/hjx/Dataset/ISPRS/Potsdam/4_Ortho_RGBIR")
# Out:
# ['top_potsdam_5_12_RGBIR.tfw',
#  'top_potsdam_7_7_RGBIR.tif',
#  'top_potsdam_3_13_RGBIR.tif',
#  'top_potsdam_5_12_RGBIR.tif',
#  'top_potsdam_6_12_RGBIR.tif',
#  'top_potsdam_3_14_RGBIR.tif',
#  'top_potsdam_7_13_RGBIR.tif',
#  'top_potsdam_7_9_RGBIR.tfw',
#  'top_potsdam_2_10_RGBIR.tif',
#  'top_potsdam_5_11_RGBIR.tif',
#  'top_potsdam_3_10_RGBIR.tif',
#  'top_potsdam_4_10_RGBIR.tif',
#  'top_potsdam_4_14_RGBIR.tif',
#  'top_potsdam_6_13_RGBIR.tfw',
#  'top_potsdam_7_7_RGBIR.tfw',
#  'top_potsdam_4_10_RGBIR.tfw',
#  'top_potsdam_7_12_RGBIR.tfw',
#  'top_potsdam_6_7_RGBIR.tfw',
#  'top_potsdam_7_9_RGBIR.tif',
#  'top_potsdam_5_11_RGBIR.tfw',
#  'top_potsdam_6_15_RGBIR.tif',
#  'top_potsdam_2_13_RGBIR.tfw',
#  'top_potsdam_2_12_RGBIR.tif',
#  'top_potsdam_5_13_RGBIR.tfw',
#  'top_potsdam_6_12_RGBIR.tfw',
#  'top_potsdam_2_11_RGBIR.tif',
#  'top_potsdam_3_14_RGBIR.tfw',
#  'top_potsdam_7_8_RGBIR.tif',
#  'top_potsdam_3_10_RGBIR.tfw',
#  'top_potsdam_4_13_RGBIR.tfw',
# ...

# %%
im = Image.open("/home/hjx/Dataset/ISPRS/Potsdam/4_Ortho_RGBIR/top_potsdam_7_7_RGBIR.tif")
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-067378ea9ea8> in <module>()
# ----> 1 im = Image.open("/home/hjx/Dataset/ISPRS/Potsdam/4_Ortho_RGBIR/top_potsdam_7_8_RGBIR.tif")
#       2 plt.imshow(im)
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2588         fp.close()
#    2589     raise IOError("cannot identify image file %r"
# -> 2590                   % (filename if filename else fp))
#    2591
#    2592 #
#
# OSError: cannot identify image file '/home/hjx/Dataset/ISPRS/Potsdam/4_Ortho_RGBIR/top_potsdam_7_8_RGBIR.tif'

# %%
tfw_file = open("/home/hjx/Dataset/ISPRS/Potsdam/4_Ortho_RGBIR/top_potsdam_5_12_RGBIR.tfw")
text = tfw_file.read()

# %%
print(text)
# Out:
#    0.050
#    0.000
#    0.000
#   -0.050
# 367576.525
# 5807662.575

# %%
os.listdir("/home/hjx/Dataset/ISPRS/Potsdam/5_Labels_for_participants_no_Boundary")
# Out:
# ['top_potsdam_6_8_label_noBoundary.tif',
#  'top_potsdam_6_7_label_noBoundary.tif',
#  'top_potsdam_2_10_label_noBoundary.tif',
#  'top_potsdam_7_9_label_noBoundary.tif',
#  'top_potsdam_5_11_label_noBoundary.tif',
#  'top_potsdam_3_12_label_noBoundary.tif',
#  'top_potsdam_6_12_label_noBoundary.tif',
#  'top_potsdam_2_11_label_noBoundary.tif',
#  'top_potsdam_5_12_label_noBoundary.tif',
#  'top_potsdam_7_7_label_noBoundary.tif',
#  'top_potsdam_6_11_label_noBoundary.tif',
#  'top_potsdam_7_8_label_noBoundary.tif',
#  'top_potsdam_3_11_label_noBoundary.tif',
#  'top_potsdam_5_10_label_noBoundary.tif',
#  'top_potsdam_3_10_label_noBoundary.tif',
#  'top_potsdam_4_12_label_noBoundary.tif',
#  'top_potsdam_7_12_label_noBoundary.tif',
#  'top_potsdam_7_11_label_noBoundary.tif',
#  'top_potsdam_6_10_label_noBoundary.tif',
#  'top_potsdam_6_9_label_noBoundary.tif',
#  'top_potsdam_2_12_label_noBoundary.tif',
#  'top_potsdam_7_10_label_noBoundary.tif',
# ...

# %%
im = Image.open("/home/hjx/Dataset/ISPRS/Potsdam/5_Labels_for_participants_no_Boundary/top_potsdam_6_8_label_noBoundary.tif")

# %%
plt.imshow(im)

# %%
os.listdir("/home/hjx/Dataset/ISPRS/Potsdam/2_Ortho_RGB")
# Out:
# ['top_potsdam_6_7_RGB.tif',
#  'top_potsdam_7_10_RGB.tif',
#  'top_potsdam_3_14_RGB.tfw',
#  'top_potsdam_2_12_RGB.tif',
#  'top_potsdam_6_13_RGB.tif',
#  'top_potsdam_7_7_RGB.tfw',
#  'top_potsdam_2_11_RGB.tfw',
#  'top_potsdam_4_10_RGB.tif',
#  'top_potsdam_7_12_RGB.tif',
#  'top_potsdam_4_13_RGB.tif',
#  'top_potsdam_7_7_RGB.tif',
#  'top_potsdam_6_10_RGB.tif',
#  'top_potsdam_5_11_RGB.tfw',
#  'top_potsdam_7_8_RGB.tif',
#  'top_potsdam_3_10_RGB.tif',
#  'top_potsdam_5_13_RGB.tif',
#  'top_potsdam_3_13_RGB.tfw',
#  'top_potsdam_4_12_RGB.tif',
#  'top_potsdam_3_12_RGB.tfw',
#  'top_potsdam_3_11_RGB.tif',
#  'top_potsdam_6_11_RGB.tfw',
#  'top_potsdam_6_9_RGB.tif',
#  'top_potsdam_4_13_RGB.tfw',
#  'top_potsdam_6_9_RGB.tfw',
#  'top_potsdam_5_15_RGB.tif',
#  'top_potsdam_3_13_RGB.tif',
#  'top_potsdam_3_14_RGB.tif',
#  'top_potsdam_2_11_RGB.tif',
#  'top_potsdam_7_8_RGB.tfw',
#  'top_potsdam_4_15_RGB.tif',
#  'top_potsdam_5_10_RGB.tfw',
#  'top_potsdam_3_10_RGB.tfw',
# ...

# %%
im = Image.open("/home/hjx/Dataset/ISPRS/Potsdam/2_Ortho_RGB/top_potsdam_6_8_RGB.tif")
file = open("/home/hjx/Dataset/ISPRS/Potsdam/2_Ortho_RGB/top_potsdam_6_8_RGB.tif","r")
content = file.read()
content
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-9937c6a630a1> in <module>()
#       1 im = Image.open("/home/hjx/Dataset/ISPRS/Potsdam/2_Ortho_RGB/top_potsdam_6_8_RGB.tif")
#       2 file = open("/home/hjx/Dataset/ISPRS/Potsdam/2_Ortho_RGB/top_potsdam_6_8_RGB.tif","r")
# ----> 3 content = file.read()
#       4 content
#
# ~/anaconda3/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcb in position 5: invalid continuation byte

# %%
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a9282a591582> in <module>()
# ----> 1 plt.imshow(im)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# ...

# %%
files = os.listdir("/home/hjx/Dataset/ISPRS/Potsdam/5_Labels_all")

# %%
for file in files:
    im = Image.open(f"/home/hjx/Dataset/ISPRS/Potsdam/5_Labels_all/{file}")
    print(im.size)
# Out:
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)
# (6000, 6000)

# %%
5632 6000
# Out:
# 11.71875

# %%
plt.imshow(im)

# %%
os.listdir("/home/hjx/Dataset/ISPRS/Potsdam/1_DSM")
# Out:
# ['dsm_potsdam_03_14.tfw',
#  'dsm_potsdam_07_08.tfw',
#  'dsm_potsdam_02_12.tif',
#  'dsm_potsdam_02_13.tif',
#  'dsm_potsdam_06_12.tif',
#  'dsm_potsdam_06_14.tif',
#  'dsm_potsdam_07_12.tif',
#  'dsm_potsdam_03_10.tfw',
#  'dsm_potsdam_02_11.tif',
#  'dsm_potsdam_05_10.tfw',
#  'dsm_potsdam_04_15.tfw',
#  'dsm_potsdam_02_10.tfw',
#  'dsm_potsdam_06_07.tif',
#  'dsm_potsdam_03_11.tif',
#  'dsm_potsdam_02_12.tfw',
#  'dsm_potsdam_07_11.tif',
#  'dsm_potsdam_06_11.tfw',
#  'dsm_potsdam_06_13.tif',
#  'dsm_potsdam_07_07.tfw',
#  'dsm_potsdam_05_11.tfw',
#  'dsm_potsdam_07_11.tfw',
#  'dsm_potsdam_03_12.tfw',
#  'dsm_potsdam_04_12.tif',
#  'dsm_potsdam_06_10.tfw',
#  'dsm_potsdam_05_15.tfw',
#  'dsm_potsdam_02_14.tif',
#  'dsm_potsdam_07_12.tfw',
#  'dsm_potsdam_07_10.tif',
#  'dsm_potsdam_05_14.tif',
#  'dsm_potsdam_02_14.tfw',
#  'dsm_potsdam_04_11.tfw',
#  'dsm_potsdam_03_12.tif',
#  'dsm_potsdam_02_10.tif',
#  'dsm_potsdam_06_10.tif',
#  'dsm_potsdam_07_13.tif',
# ...

# %%
im = Image.open("/home/hjx/Dataset/ISPRS/Potsdam/1_DSM/dsm_potsdam_06_08.tif")
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in pil_to_array(pilImage)
#    1454         try:
# -> 1455             pilImage = pilImage.convert('RGBA')
#    1456         except ValueError:
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     878
# --> 879         self.load()
#     880
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py in load(self)
#    1053             return self._load_libtiff()
# -> 1054         return super(TiffImageFile, self).load()
#    1055
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py in load(self)
#     206                     seek(offset)
# --> 207                     decoder.setimage(self.im, extents)
#     208                     if decoder.pulls_fd:
#
# ...
